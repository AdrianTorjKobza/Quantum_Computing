# %%
from qiskit import *
from qiskit.tools.visualization import plot_histogram, array_to_latex, plot_bloch_multivector, plot_state_qsphere
from math import pi
# %matplotlib inline

# %%
circuit = QuantumCircuit(3) # Quantum Circuit with 3 qubits.
circuit.h([0, 1, 2])  # Apply the Hadmard gate on all qubits.
circuit.s(1)  # Apply the S gate (shift by 90 degrees) on the second qubit.
circuit.sdg(2)  # Apply the S-Dagger gate (shift by -90 degrees) on the third qubit.
print(circuit)
circuit.draw(output = 'mpl') # Draw the circuit diagram.
# Out:
#      ┌───┐
# q_0: ┤ H ├───────
#      ├───┤ ┌───┐
# q_1: ┤ H ├─┤ S ├─
#      ├───┤┌┴───┴┐
# q_2: ┤ H ├┤ Sdg ├
#      └───┘└─────┘

# %%
simulator = Aer.get_backend('statevector_simulator') # Simulate the QC execution.
result = execute(circuit, backend=simulator).result()
state_vector = result.get_statevector()
array_to_latex(state_vector, prefix="\\text{State Vector = }\n") # Visual representation of the vector.
# Out:
# $$
# \text{State Vector = }
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{4} & \frac{\sqrt{2}}{4} & \frac{\sqrt{2} i}{4} & \frac{\sqrt{2} i}{4} & - \frac{\sqrt{2} i}{4} & - \frac{\sqrt{2} i}{4} & \frac{\sqrt{2}}{4} & \frac{\sqrt{2}}{4}  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(state_vector) # Vector visualization on the bloch sphere.

# %%
circuit = QuantumCircuit(3) # Quantum Circuit with 3 qubits.
circuit.h([0, 1, 2])  # Apply the Hadmard gate on all qubits.
circuit.t(1)  # Apply the T gate (shift by 45 degrees) on the second qubit.
circuit.tdg(2)  # Apply the T-Dagger gate (shift by -45 degrees) on the third qubit.
print(circuit)
circuit.draw(output = 'mpl') # Draw the circuit diagram.
# Out:
#      ┌───┐
# q_0: ┤ H ├───────
#      ├───┤ ┌───┐
# q_1: ┤ H ├─┤ T ├─
#      ├───┤┌┴───┴┐
# q_2: ┤ H ├┤ Tdg ├
#      └───┘└─────┘

# %%
simulator = Aer.get_backend('statevector_simulator') # Simulate the QC execution.
result = execute(circuit, backend=simulator).result()
state_vector = result.get_statevector()
array_to_latex(state_vector, prefix="\\text{State Vector = }\n") # Visual representation of the vector.
# Out:
# $$
# \text{State Vector = }
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{4} & \frac{\sqrt{2}}{4} & \frac{1}{4} + \frac{i}{4} & \frac{1}{4} + \frac{i}{4} & \frac{1}{4} - \frac{i}{4} & \frac{1}{4} - \frac{i}{4} & \frac{\sqrt{2}}{4} & \frac{\sqrt{2}}{4}  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(state_vector) # Vector visualization on the bloch sphere.
